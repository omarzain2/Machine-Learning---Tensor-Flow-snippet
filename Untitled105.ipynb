# %%
import sklearn
from sklearn.utils import shuffle 
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

# %%
data = pd.read_csv("/Users/zain/Downloads/car.data")
data = data.rename(columns={"vhigh": "buying", "vhigh.1": "maint", "2": "door", "2.1": "persons", "small": "lug_boot", "low": "safety", "unacc": "class"})
data.head(10)
# Out:
#   buying  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    med  unacc
# 1  vhigh  vhigh    2       2    small   high  unacc
# 2  vhigh  vhigh    2       2      med    low  unacc
# 3  vhigh  vhigh    2       2      med    med  unacc
# 4  vhigh  vhigh    2       2      med   high  unacc
# 5  vhigh  vhigh    2       2      big    low  unacc
# 6  vhigh  vhigh    2       2      big    med  unacc
# 7  vhigh  vhigh    2       2      big   high  unacc
# 8  vhigh  vhigh    2       4    small    low  unacc
# 9  vhigh  vhigh    2       4    small    med  unacc

# %%
le = preprocessing.LabelEncoder()

buying = le.fit_transform(list(data["buying"]))
maint = le.fit_transform(list(data["maint"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
cls = le.fit_transform(list(data["class"]))

predict = "class"

x = list(zip(buying,maint,lug_boot,safety))
y = list(cls)

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size =0.10)

# %%
print(x_train, y_test)
# Out:
# [(3, 0, 1, 2), (0, 3, 0, 2), (0, 0, 0, 0), (2, 1, 2, 1), (2, 2, 1, 2), (0, 2, 0, 1), (2, 1, 0, 0), (0, 2, 2, 0), (3, 3, 2, 2), (2, 0, 1, 2), (3, 2, 1, 0), (3, 1, 2, 0), (3, 1, 1, 0), (2, 3, 2, 2), (1, 0, 1, 0), (0, 2, 0, 0), (0, 1, 2, 1), (3, 1, 0, 0), (2, 0, 1, 2), (3, 0, 1, 0), (0, 0, 0, 2), (3, 2, 1, 2), (3, 1, 1, 2), (1, 3, 0, 0), (2, 0, 1, 2), (3, 3, 2, 0), (3, 2, 1, 2), (2, 1, 2, 1), (1, 0, 0, 0), (1, 0, 1, 0), (3, 3, 0, 0), (1, 1, 0, 1), (0, 0, 2, 2), (0, 0, 1, 1), (3, 3, 0, 0), (1, 3, 2, 2), (2, 1, 1, 1), (3, 1, 1, 1), (1, 0, 0, 2), (0, 2, 0, 1), (1, 3, 2, 0), (3, 0, 0, 1), (0, 3, 0, 2), (3, 1, 0, 0), (2, 1, 1, 1), (3, 2, 2, 0), (0, 3, 1, 1), (0, 3, 1, 1), (0, 2, 1, 1), (1, 1, 2, 2), (2, 0, 0, 2), (0, 1, 0, 1), (0, 1, 2, 2), (1, 2, 0, 1), (3, 3, 1, 0), (2, 3, 1, 2), (1, 3, 0, 2), (3, 1, 0, 1), (0, 2, 1, 0), (1, 0, 2, 0), (1, 1, 2, 2), (0, 3, 0, 0), (2, 3, 0, 1), (0, 1, 2, 0), (2, 2, 0, 0), (3, 0, 2, 0), (2, 0, 2, 2), (1, 0, 0, 2), (3, 0, 1, 2), (1, 0, 0, 2), (2, 2, 2, 1), (0,
# ...

# %%
best_score = 0

for i in range(10):
    model = KNeighborsClassifier(n_neighbors = 4)
    model.fit(x_train,y_train)
    acc = model.score(x_test,y_test)
    
    if acc > best_score:
        best_score = acc
        

    

predicted = model.predict(x_test)
names = ["unacc","acc","good","vgood"]

for x in range(len(predicted)):
    print("Predicted: " , names[predicted[x]], "Data: ", x_test[x], "Actual: ", names[y_test[x]])
    #n = model.kneighbors([x_test[x]],9,True)
    #print(n)
# Out:
# Predicted:  unacc Data:  (1, 0, 2, 0) Actual:  unacc
# Predicted:  good Data:  (3, 2, 2, 1) Actual:  good
# Predicted:  good Data:  (2, 3, 2, 1) Actual:  good
# Predicted:  unacc Data:  (1, 0, 1, 2) Actual:  good
# Predicted:  good Data:  (2, 2, 2, 1) Actual:  good
# Predicted:  good Data:  (0, 3, 0, 1) Actual:  good
# Predicted:  unacc Data:  (2, 0, 1, 0) Actual:  good
# Predicted:  acc Data:  (1, 2, 1, 2) Actual:  good
# Predicted:  unacc Data:  (0, 2, 1, 2) Actual:  good
# Predicted:  good Data:  (0, 2, 2, 2) Actual:  good
# Predicted:  unacc Data:  (0, 2, 0, 0) Actual:  good
# Predicted:  good Data:  (2, 3, 1, 1) Actual:  good
# Predicted:  acc Data:  (1, 2, 2, 0) Actual:  acc
# Predicted:  good Data:  (0, 0, 2, 2) Actual:  good
# Predicted:  good Data:  (3, 2, 2, 2) Actual:  good
# Predicted:  unacc Data:  (3, 2, 0, 2) Actual:  unacc
# Predicted:  good Data:  (3, 2, 2, 2) Actual:  good
# Predicted:  good Data:  (3, 0, 1, 1) Actual:  good
# ...

# %%
best_score
# Out:
# 0.7861271676300579

# %%
best_score
# Out:
# 0.7861271676300579
